# %% [markdown]
# 11.3.1. Напишите программу, которая заполняет список из 100 элементов случайными числами в диапазоне от 1 до 50, и затем выводит их сумму и среднее. Следующие упражнения выполняйте на основе этого кода (есть готовый массив со случайными значениями).

# %%
import random

summ=0
average=0
x=[]

for i in range(100):
    x.append(random.randint(0,50))
    summ+=x[i]
    average=summ/len(x)

print("Summ x list: " + str(summ))
#print(x)
print("Average : "+str(average))
print("Lenth x is :"+str(len(x)))
# Out:
# Summ x list: 2430
# Average : 24.3
# Lenth x is :100

# %% [markdown]
# 11.3.2. Напишите программу, которая находит в массиве введенное с клавиатуры значение и выводит его индекс (номер нахождения в массиве, начиная с нуля). Используйте break, чтобы при нахождении нужного значения не продолжать цикл.

# %%
num=int(input("Enter number: "))

for i in range(len(x)):
    if x[i]==num:
        print("Position "+str(num)+" in x is : "+str(i))
        print(x)
        break
# Out:
# Enter number: 21
# Position 21 in x is : 40
# [11, 27, 15, 31, 12, 33, 40, 33, 0, 18, 4, 32, 8, 10, 41, 31, 10, 40, 29, 4, 37, 15, 6, 42, 50, 22, 3, 7, 29, 24, 17, 34, 36, 39, 42, 38, 15, 2, 9, 28, 21, 2, 31, 29, 3, 41, 24, 30, 45, 21, 37, 20, 45, 44, 38, 26, 27, 9, 17, 42, 17, 37, 2, 9, 10, 34, 1, 33, 19, 28, 34, 42, 44, 50, 19, 20, 17, 20, 14, 16, 13, 39, 3, 1, 20, 35, 10, 46, 1, 14, 36, 43, 10, 44, 26, 30, 7, 37, 35, 38]

# %% [markdown]
# 11.3.3. Напишите программу, которая находит минимальное и максимальное значения в массиве.

# %%
min=max=x[0]


for i in range(len(x)):
    
    if x[i]>=max:
        max=x[i]
    if x[i]<=min:
        min=x[i]
        
print(x)
print("max is: "+str(max)+" min is: "+str(min))
# Out:
# [11, 27, 15, 31, 12, 33, 40, 33, 0, 18, 4, 32, 8, 10, 41, 31, 10, 40, 29, 4, 37, 15, 6, 42, 50, 22, 3, 7, 29, 24, 17, 34, 36, 39, 42, 38, 15, 2, 9, 28, 21, 2, 31, 29, 3, 41, 24, 30, 45, 21, 37, 20, 45, 44, 38, 26, 27, 9, 17, 42, 17, 37, 2, 9, 10, 34, 1, 33, 19, 28, 34, 42, 44, 50, 19, 20, 17, 20, 14, 16, 13, 39, 3, 1, 20, 35, 10, 46, 1, 14, 36, 43, 10, 44, 26, 30, 7, 37, 35, 38]
# max is: 50 min is: 0

# %% [markdown]
# 11.3.4. Напишите программу, которая находит второй по величине элемент массива.

# %%
import random

c=[]

for i in range(20):
    c.append(random.randint(1,100))
print(c)

b=1

while b<len(c):
    for i in range(len(c)-b):
        if c[i]>c[i+1]:
            buffer=c[i+1]
            c[i+1]=c[i]
            c[i]=buffer
            
    b+=1
print(c)

print(c[len(c)-2])
# Out:
# [27, 13, 67, 87, 6, 17, 68, 19, 9, 99, 51, 93, 11, 84, 58, 84, 78, 52, 24, 11]
# [6, 9, 11, 11, 13, 17, 19, 24, 27, 51, 52, 58, 67, 68, 78, 84, 84, 87, 93, 99]
# 93

# %% [markdown]
# 11.3.5. Напишите программу, которая "обращает" массив -- записывает в него значения в обратном порядке, от конца к началу.

# %%
k=[]

for i in range(len(x)):

    k.append(x[(len(x)-1)-i])
    
print(x)
print("")
print(k)
# Out:
# [11, 27, 15, 31, 12, 33, 40, 33, 0, 18, 4, 32, 8, 10, 41, 31, 10, 40, 29, 4, 37, 15, 6, 42, 50, 22, 3, 7, 29, 24, 17, 34, 36, 39, 42, 38, 15, 2, 9, 28, 21, 2, 31, 29, 3, 41, 24, 30, 45, 21, 37, 20, 45, 44, 38, 26, 27, 9, 17, 42, 17, 37, 2, 9, 10, 34, 1, 33, 19, 28, 34, 42, 44, 50, 19, 20, 17, 20, 14, 16, 13, 39, 3, 1, 20, 35, 10, 46, 1, 14, 36, 43, 10, 44, 26, 30, 7, 37, 35, 38]
#
# [38, 35, 37, 7, 30, 26, 44, 10, 43, 36, 14, 1, 46, 10, 35, 20, 1, 3, 39, 13, 16, 14, 20, 17, 20, 19, 50, 44, 42, 34, 28, 19, 33, 1, 34, 10, 9, 2, 37, 17, 42, 17, 9, 27, 26, 38, 44, 45, 20, 37, 21, 45, 30, 24, 41, 3, 29, 31, 2, 21, 28, 9, 2, 15, 38, 42, 39, 36, 34, 17, 24, 29, 7, 3, 22, 50, 42, 6, 15, 37, 4, 29, 40, 10, 31, 41, 10, 8, 32, 4, 18, 0, 33, 40, 33, 12, 31, 15, 27, 11]

# %% [markdown]
# 11.3.6. Напишите программу, которая копирует один массив в другой.

# %%
g=[]

for i in range(1):
    g.append(x)

print(x)
print(" ")
print(g)
# Out:
# [11, 27, 15, 31, 12, 33, 40, 33, 0, 18, 4, 32, 8, 10, 41, 31, 10, 40, 29, 4, 37, 15, 6, 42, 50, 22, 3, 7, 29, 24, 17, 34, 36, 39, 42, 38, 15, 2, 9, 28, 21, 2, 31, 29, 3, 41, 24, 30, 45, 21, 37, 20, 45, 44, 38, 26, 27, 9, 17, 42, 17, 37, 2, 9, 10, 34, 1, 33, 19, 28, 34, 42, 44, 50, 19, 20, 17, 20, 14, 16, 13, 39, 3, 1, 20, 35, 10, 46, 1, 14, 36, 43, 10, 44, 26, 30, 7, 37, 35, 38]
#
# [[11, 27, 15, 31, 12, 33, 40, 33, 0, 18, 4, 32, 8, 10, 41, 31, 10, 40, 29, 4, 37, 15, 6, 42, 50, 22, 3, 7, 29, 24, 17, 34, 36, 39, 42, 38, 15, 2, 9, 28, 21, 2, 31, 29, 3, 41, 24, 30, 45, 21, 37, 20, 45, 44, 38, 26, 27, 9, 17, 42, 17, 37, 2, 9, 10, 34, 1, 33, 19, 28, 34, 42, 44, 50, 19, 20, 17, 20, 14, 16, 13, 39, 3, 1, 20, 35, 10, 46, 1, 14, 36, 43, 10, 44, 26, 30, 7, 37, 35, 38]]

# %% [markdown]
# 11.3.7.Напишите программу, которая печатает элементы, одновременно присутствующие в двух массивах (предварительно заполните их случайными числами). Используйте вложенные циклы.

# %%
o=[]
for i in range(100):
    o.append(random.randint(0,100))

print(x)
print(" ")
print(o)
#print(len(o))
print(" ")
for i in range(len(x)):
    for j in range(len(o)):
        if x[i]==o[j]:
            print(x[i])
# Out:
# [11, 27, 15, 31, 12, 33, 40, 33, 0, 18, 4, 32, 8, 10, 41, 31, 10, 40, 29, 4, 37, 15, 6, 42, 50, 22, 3, 7, 29, 24, 17, 34, 36, 39, 42, 38, 15, 2, 9, 28, 21, 2, 31, 29, 3, 41, 24, 30, 45, 21, 37, 20, 45, 44, 38, 26, 27, 9, 17, 42, 17, 37, 2, 9, 10, 34, 1, 33, 19, 28, 34, 42, 44, 50, 19, 20, 17, 20, 14, 16, 13, 39, 3, 1, 20, 35, 10, 46, 1, 14, 36, 43, 10, 44, 26, 30, 7, 37, 35, 38]
#
# [16, 57, 19, 78, 32, 47, 67, 0, 28, 10, 87, 35, 98, 21, 96, 76, 92, 75, 38, 57, 67, 10, 100, 84, 36, 56, 83, 52, 46, 3, 21, 1, 0, 72, 89, 50, 68, 42, 6, 21, 92, 69, 58, 72, 72, 29, 8, 14, 75, 57, 79, 91, 15, 10, 43, 34, 81, 38, 90, 93, 19, 19, 86, 71, 97, 74, 86, 55, 53, 87, 24, 10, 36, 38, 63, 82, 38, 22, 2, 10, 25, 98, 55, 86, 87, 76, 20, 76, 2, 37, 26, 99, 46, 7, 97, 46, 20, 27, 53, 56]
#
# 27
# 15
# 0
# 0
# 32
# 8
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 29
# 37
# 15
# 6
# 42
# 50
# 22
# 3
# 7
# 29
# 24
# 34
# 36
# 36
# 42
# 38
# 38
# 38
# 38
# 15
# 2
# 2
# 28
# 21
# 21
# 21
# 2
# 2
# 29
# ...

# %% [markdown]
# 11.3.8. Напишите программу, которая сортирует массив из 10 элементов по возрастанию.

# %%
import random

q=[]

for i in range(10):
    q.append(random.randint(0,1000))
    
print(q)
print(len(q))
# Out:
# [874, 726, 43, 44, 603, 270, 302, 305, 784, 803]
# 10

# %%
import random

q=[]

for i in range(10):
    q.append(random.randint(0,1000))
    
#print(q)
#print(len(q))



print(q)
n=1
while n<len(q):
    for i in range(len(q)-n):
        if q[i]>q[i+1]:
            buffer=q[i+1]
            q[i+1]=q[i]
            q[i]=buffer
    n+=1
print(q)
# Out:
# [969, 477, 163, 477, 654, 123, 260, 265, 874, 51]
# [51, 123, 163, 260, 265, 477, 477, 654, 874, 969]

# %%
# Не пойму почему практически такой же код но циклы через for, выдает ошибку, выход за границы массива:

import random

q=[]

for i in range(10):
    q.append(random.randint(0,1000))
    
print(q)
print(len(q))



print(q)
n=1
for n in range(len(q)):
    for i in range(len(q)-n):
        if q[i]>q[i+1]:
            buffer=q[i+1]
            q[i+1]=q[i]
            q[i]=buffer
    n+=1
print(q)

# %% [markdown]
# 11.3.9. Реализуйте логику метания кубиков из игры Dungeons & Dragons. Логика кубика записывается формулой NdM, где N -- количество кубиков, а M -- количество граней каждого кубика. Например, 3d12 означает бросок трёх двенадцатигранных кубиков. Соответственно, минимально может выпасть 3, а максимально 36.
# Вам надо вывести результат метания кубика, для которого введены N и M.

# %%
N=int(input())
M=int(input())

min=N*1
max=M*N

print("max is: "+str(max)+" min is : "+str(min))
# Out:
# 3
# 3
# max is: 9 min is : 3
